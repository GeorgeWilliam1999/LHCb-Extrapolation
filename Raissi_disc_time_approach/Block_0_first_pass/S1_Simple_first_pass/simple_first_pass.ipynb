# %% [markdown]
# # Step 1 — the exact scheme, no network
#
# Feasibility + ceiling of the q-stage Gauss-Legendre scheme on real legs. See README.md.

# %%
import pandas as pd
a = pd.read_csv('results/scheme_error_vs_q.csv')
a

# %%
# headline: one implicit step across the magnet
a[a.leg=='B'][['q','converged_frac','median_err_mm','worst_err_mm','median_nev']]

# %%
from IPython.display import Image
Image('figures/scheme_error_vs_q.png')
