# %% [markdown]
# # Step 0 — baseline data exploration
#
# The reference card + the measured scales the discrete-time loss needs. See README.md.

# %%
import json
from reference_card import card, load_training
print(json.dumps(card(), indent=1))

# %%
import json
print(json.dumps(json.load(open('results/scales.json')), indent=1))

# %%
import pandas as pd
pd.read_csv('results/scales.csv')

# %%
from IPython.display import Image
Image('figures/field_along_legs.png')
