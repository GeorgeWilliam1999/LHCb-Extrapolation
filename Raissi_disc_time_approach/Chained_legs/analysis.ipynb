# %% [markdown]
# # A3b — chaining the network along real particle paths
#
# Loads only. The chains, the RK4 reference paths and the scores were written by
# `build_chains.py` and `chain.py`; the figures by `plot_chains.py`.
#
# | script | output |
# |---|---|
# | `build_chains.py` | `results/chains_{test,val}.npz`, `results/leg_d_test.npz`, `results/chains_meta.json` |
# | `chain.py` | `results/chain_summary.csv`, `results/chains.csv`, `results/selection.csv`, `results/leg_d_reproduction.csv`, `results/example_paths.npz` |
# | `plot_chains.py` | the three figures |

# %%
import json
import pandas as pd
from IPython.display import Image, display

meta = json.load(open("results/chains_meta.json"))
print(meta["rule"])
for s in ("test", "val"):
    print(s, meta[s]["particles_kept"], "particles,", meta[s]["legs_total"],
          "legs, lengths", meta[s]["n_legs_histogram"])
meta["leg_d_test"]
# Out:
# per particle: forward rows only; the planes they name, sorted and uniqued to 3 decimals, are the waypoints; consecutive waypoints are the legs; keep >= 4 legs
# test 4563 particles, 23500 legs, lengths {'4': 1649, '5': 1433, '6': 628, '7': 853}
# val 4551 particles, 23516 legs, lengths {'4': 1619, '5': 1408, '6': 668, '7': 856}
# {'split': 'test',
#  'particles_with_D_leg': 2726,
#  'waypoint_from_own_B_leg': 1637,
#  'waypoint_from_frozen_leg_z0': 1089,
#  'dz_first_step_mm_median': -5178.247045898437,
#  'dz_second_step_mm_median': -2651.4154677152633,
#  'dz_whole_leg_mm_median': -7853.16176700592}

# %% [markdown]
# ## How the error grows with the number of legs walked

# %%
cs = pd.read_csv("results/chain_summary.csv")
cs[(cs.split == "test") & cs.converged].pivot_table(
    index="step", columns=["width", "mode"], values="end_med_um",
    aggfunc="median")
# Out:
# width           50                         100
# mode           data       physics         data       physics
# step
# 0        387.837388    440.312607   216.793457    246.257071
# 1       1275.180079   1422.921684   651.616873    783.237395
# 2       2225.477703   2562.360316  1051.090407   1443.327676
# 3       3634.496891   3919.235020  1483.790811   2292.650199
# 4       6991.423832   8162.983499  2868.657354   4830.864957
# 5      10086.651796  14479.118125  4819.579012   8904.428039
# 6      10738.884793  15999.145719  5283.457377  10247.902518

# %%
display(Image("figures/error_vs_chained_legs.png"))

# %% [markdown]
# ## Which seed the val chains select, and whether the one-step error would have selected it

# %%
sel = pd.read_csv("results/selection.csv")
sel
# Out:
#     width     mode          network  rank_by_val_chain  chain_val_leg4_med_um  \
# 0      50  physics   w50_physics_s6                0.0            3715.149520
# 1      50  physics   w50_physics_s1                1.0            3776.588421
# 2      50  physics   w50_physics_s8                2.0            3997.255061
# 3      50  physics   w50_physics_s4                3.0            4041.210460
# 4      50  physics   w50_physics_s9                4.0            4109.867323
# 5      50  physics   w50_physics_s0                5.0            4196.972117
# 6      50  physics   w50_physics_s7                6.0            4543.111356
# 7      50  physics   w50_physics_s5                7.0            4775.015314
# 8      50  physics   w50_physics_s2                8.0            5610.923012
# 9      50  physics   w50_physics_s3                9.0            6564.542055
# 10     50  physics         SPEARMAN                NaN               0.915152
# 11     50     data      w50_data_s2                0.0            3694.902319
# 12     50     data      w50_data_s1                1.0            3932.013052
# 13     50     data      w50_data_s0                2.0            4137.840231
# 14     50     data         SPEARMAN                NaN              -0.500000
# 15    100  physics  w100_physics_s6                0.0            2086.279506
# 16    100  physics  w100_physics_s8                1.0            2190.001300
# 17    100  physics  w100_physics_s5                2.0            2208.872767
# 18    100  physics  w100_physics_s4                3.0            2373.514557
# 19    100  physics  w100_physics_s9                4.0            2391.076664
# 20    100  physics  w100_physics_s1                5.0            2412.624737
# 21    100  physics  w100_physics_s3                6.0            2443.288556
# 22    100  physics  w100_physics_s2                7.0            2484.229535
# 23    100  physics  w100_physics_s0                8.0            2683.496598
# 24    100  physics  w100_physics_s7                9.0            2803.432907
# 25    100  physics         SPEARMAN                NaN               0.951515
# 26    100     data     w100_data_s2                0.0            1489.387180
# 27    100     data     w100_data_s0                1.0            1563.424608
# 28    100     data     w100_data_s1                2.0            2051.014250
# 29    100     data         SPEARMAN                NaN               1.000000
#
#     chain_test_leg4_med_um  one_step_val_med_um  \
# 0              3408.662495           661.240617
# 1              3680.501583           724.725816
# 2              3704.957041           782.073766
# 3              3792.779359           650.297173
# 4              3570.681792           639.829759
# 5              4045.690681           854.349431
# 6              4274.647693           736.338829
# 7              4237.791245           737.375317
# 8              5363.211365          1246.374606
# 9              6122.072714           884.710497
# 10                0.757576             0.648485
# 11             3634.496891           633.517731
# 12             4025.366540           645.556675
# 13             3571.215290           594.239448
# 14                1.000000            -0.500000
# 15             1975.013405           391.957360
# 16             2054.366074           389.191847
# 17             2102.039241           373.125352
# 18             2186.584840           413.012216
# 19             2289.594308           415.828084
# 20             2303.267121           338.689395
# 21             2342.769177           431.784729
# 22             2295.706090           389.952486
# 23             2582.639602           351.806455
# 24             2580.498364           426.985460
# 25                0.078788             0.151515
# 26             1403.333078           245.917639
# 27             1483.790811           315.552462
# 28             2015.057039           348.014311
# 29                1.000000             1.000000
#
#                                              selected
# 0                                                True
# 1                                               False
# 2                                               False
# 3                                               False
# 4                                               False
# 5                                               False
# 6                                               False
# 7                                               False
# 8                                               False
# 9                                               False
# 10  columns: val-chain vs test-chain | one-step-va...
# 11                                               True
# 12                                              False
# 13                                              False
# 14  columns: val-chain vs test-chain | one-step-va...
# 15                                               True
# 16                                              False
# 17                                              False
# 18                                              False
# 19                                              False
# 20                                              False
# 21                                              False
# 22                                              False
# 23                                              False
# 24                                              False
# 25  columns: val-chain vs test-chain | one-step-va...
# 26                                               True
# 27                                              False
# 28                                              False
# 29  columns: val-chain vs test-chain | one-step-va...

# %% [markdown]
# ## A few particles drawn out

# %%
display(Image("figures/error_growth_examples.png"))

# %% [markdown]
# ## Leg D: the same leg in two steps instead of one

# %%
d = pd.read_csv("results/leg_d_reproduction.csv")
d.pivot_table(index=["width", "mode"], columns="variant", values="med_um",
              aggfunc="median")
# Out:
# variant        composite_two_steps  single_giant_step
# width mode
# 50    data            34228.293813        6213.119116
#       physics         47353.077903       17947.491518
# 100   data            33416.449508        3158.441764
#       physics         59415.521643        8777.606848

# %%
display(Image("figures/leg_d_reproduction.png"))
